# %% [markdown]
# <a href="https://colab.research.google.com/github/Izabella-g-santos/AulaFCE/blob/main/P2_Izabella_Gabriel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 **Fundamentos Computacionais para Engenharia**
#
# ## Segunda Avaliação
# ---
# ***

# %% [markdown]
# Izabella Gabriel dos Santos - 2021101263
#
# ***

# %% [markdown]
# ##**Parte 1** - Conceitos Fundamentais (teoria e compreensão)
# ---
# #### **Questão 1**. A Programação Orientada a Equações (POE) é um paradigma que permite ao programador descrever um problema com foco em sua estrutura lógica, aproximando a modelagem computacional das equações matemáticas do processo físico.
#
# **a)** Explique como a POE difere da programação imperativa, considerando o papel do programador e o processo de obtenção da solução.
#
# #####<font color = blue> A Programação Orientada a Equações (POE) e a programação imperativa têm abordagens bem distintas quando o assunto é resolver problemas. A principal diferença está em como a solução é formulada e no papel de quem a programa. Enquanto a programação imperativa se prende ao "como fazer", detalhando cada passo e o fluxo de execução, a POE foca no "o quê", ou seja, em definir o problema através de equações que descrevem as relações entre as variáveis.
#
# #####<font color = blue>Na POE, o programador atua como um modelador. Ele descreve o sistema usando equações matemáticas de forma declarativa, sem se preocupar com a ordem de execução ou o controle do estado do programa.Por outro lado, na abordagem imperativa, é o programador quem tem que controlar explicitamente o estado do programa e a sequência exata de instruções para chegar à solução.
#
# #####<font color = blue>Por isso, na POE, o trabalho de encontrar a solução pode ser delegado a um sistema especializado (como um solucionador simbólico ou numérico). Na programação imperativa, essa responsabilidade de "guiar" o processo é inteiramente do programador.</font>
# \
# **b)** Em que tipo de problema de engenharia a POE é mais vantajosa? Cite pelo menos um exemplo prático — diferente dos discutidos em sala.
# #####<font color = blue> A Programação Orientada a Equações (POE) é especialmente vantajosa para problemas de engenharia que envolvem modelagem matemática complexa, principalmente quando lidamos com muitas variáveis interligadas por equações diferenciais. Ela simplifica a forma como descrevemos sistemas complexos.
#
# #####<font color = blue>Um exemplo prático do uso da POE é na engenharia biomédica, em particular na simulação de sistemas biomecânicos. Imagine, por exemplo, a necessidade de representar o movimento de articulações humanas, como o joelho durante uma caminhada.
#
# #####<font color = blue>Nesse cenário, a POE permite modelar o sistema considerando as diversas forças envolvidas (musculares, gravitacionais e de contato) em conjunto com as equações de movimento que descrevem o comportamento dos segmentos do corpo. A grande vantagem é que todas essas relações complexas são expressas diretamente como equações matemáticas, sem a necessidade de especificar a sequência de cálculos passo a passo. Isso simplifica significativamente a criação e a análise de modelos, tornando o processo mais intuitivo e menos propenso a erros de implementação de fluxo de controle.
#
# #####<font color = blue>Essa abordagem facilita a análise do desempenho de próteses ou o estudo da eficácia de tratamentos, exigindo menos esforço de programação. Ferramentas como o OpenSim ou o Modelica são frequentemente usadas nesses contextos.</font>
#
# \
# **c)** Um dos princípios mais valorizados da POE é a flexibilidade. O que esse princípio significa na prática? Por que ele é útil para o engenheiro químico?
# #####<font color = blue> A flexibilidade é, de fato, um dos grandes trunfos da POE. Na prática, esse princípio significa que a POE é extremamente versátil, permitindo sua aplicação em uma vasta gama de cenários, modelos e condições sem a necessidade de reestruturar o código a cada alteração. Para o engenheiro, isso se traduz na liberdade de ajustar parâmetros, modificar equações ou simular novas situações com grande facilidade e agilidade.
#
# #####<font color = blue> Essa característica é de suma importância para o engenheiro químico. A engenharia química por si só, lida com uma enorme diversidade de processos e sistemas, como reações químicas, trocas térmicas, escoamento de fluidos, dentre muitos outros. Estes possuem a necessidade de frequentemente serem adaptados a diferentes condições operacionais.
#
# #####<font color = blue> Com a flexibilidade da POE, o engenheiro químico pode testar alternativas, otimizar processos e adaptar modelos de forma muito mais rápida e eficiente. Isso agiliza o desenvolvimento e a melhoria contínua de processos industriais, permitindo uma resposta mais ágil às demandas e desafios do setor.</font>
#
# \
#
# ---
# #### **Questão 2**. Ao desenvolver soluções computacionais, a organização do código é essencial para sua manutenção, reusabilidade e adaptação a novos cenários.
#
#
# 1. Explique o papel da estrutura @dataclass em Python na organização dos códigos. Por que ela é especialmente útil em sistemas com muitos parâmetros de entrada?.
#
#      <font color= blue>A estrutura `@dataclass` em Python é uma forma prática e eficiente de organizar dados que pertencem a um mesmo contexto. Com ela, é possível agrupar várias variáveis relacionadas em uma única classe, de maneira clara e compacta. Isso melhora não só a legibilidade do código, mas também a sua manutenção e reutilização ao longo do tempo.
#
#      Em sistemas que envolvem muitos parâmetros de entrada, ela se torna ainda mais útil. Isso porque permite armazenar todos esses dados de forma estruturada, sem precisar se preocupar tanto com a ordem dos argumentos. Assim, o código fica mais confiável, evita erros comuns e facilita o trabalho do programador na hora de manipular ou passar esses dados entre funções ou módulos. </font>
#
# \
#
# 2.   Por que se recomenda salvar as soluções em repositórios como o GitHub? Cite três benefícios práticos, relacionando-os com a prática profissional ou acadêmica.
#
#      <font color = blue> Salvar as soluções em repositórios como o GitHub é altamente recomendado tanto no meio acadêmico quanto profissional por diversos motivos.
#
#       <font color = blue> Primeiro benefício reside no controle de versões, que permite acompanhar o histórico de alterações no código, facilitando a identificação de melhorias ou erros, além de permitir voltar a versões anteriores, se necessário. Segundo beníficio do GitHub é contribuir com a reprodutibilidade dos resultados: qualquer pessoa com acesso ao repositório pode executar o mesmo código e obter os mesmos resultados, o que é essencial em trabalhos científicos e projetos colaborativos.
#
#      Por fim, há o benefício do compartilhamento e colaboração. Repositórios podem ser facilmente acessados por colegas, professores ou equipes de trabalho, permitindo revisões, sugestões e integração com ferramentas como notebooks de simulação. Cada versão salva representa um ponto de desenvolvimento do projeto, o que facilita testes, comparações e ajustes contínuos.</font>

# %% [markdown]
# ##**Parte 2 - Aplicações e lógica computacional (modelagem e simulação)**
# ####*Você deverá implementar soluções em Python para os problemas apresentados, utilizando boas práticas de programação e estruturas típicas, como funções, loops e `@dataclass`.Comente sempre seu código e publique suas soluções em um repositório no GitHub.*
#
# \
#
# ---
# #### **Questão 3**. Fermentação alcoólica com cinética dependente da temperatura - Um processo em batelada converte glicose em etanol e CO2. A taxa de consumo da glicose depende da temperatura segundo a expressão:
#
# ![image.png](data:image/png;base64,...)
#
# A cinética é de primeira ordem, tal que:
#
# ![image.png](data:image/png;base64,...)
#
# Considerando concentração inicial S(t = 0) de glicose igual a 100 g/L e temperatura constante de 35°C, implemente uma solução computacional para simular a concentração de glicose ao longo de 24 horas. Qual o valor final da concentração de glicose? O que acontece se a temperatura for aumentada para 50°C?

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from dataclasses import dataclass

@dataclass
class ParametrosBatelada:
    T: float = 35.0     # Temperatura em °C
    S0: float = 100.0   # Concentração inicial de glicose (g/L)

def modelo_batelada(t, y, params):
    S = y[0]
    T_kelvin = params.T + 273
    k = 464.8 * np.exp(-3985 / T_kelvin)  # [1/min]
    dSdt = -k * S
    return [dSdt]

def simula_batelada(tempo, params):
    teval = np.linspace(tempo[0], tempo[-1], 100)
    sol = solve_ivp(modelo_batelada, tempo, [params.S0], t_eval=teval, method='BDF', args=(params,))
    return sol.t, sol.y[0]

# Simulações para T = 35°C e T = 50°C
conjuntos = [
    ParametrosBatelada(T=35.0),
    ParametrosBatelada(T=50.0)
]

tempo = [0, 24*60]  # tempo em minutos

for params in conjuntos:
    t, S = simula_batelada(tempo, params)
    print(f"Temperatura: {params.T} °C --> Concentração final: S = {S[-1]:.4f} g/L")
    plt.plot(t, S, label=f"T = {params.T} °C")

plt.xlabel("Tempo (min)")
plt.ylabel("Concentração de glicose (g/L)")
plt.title("Consumo de glicose ao longo de 24h")
plt.legend()
plt.grid()
plt.show()
# Out:
# Temperatura: 35.0 °C --> Concentração final: S = 20.0053 g/L
# Temperatura: 50.0 °C --> Concentração final: S = 5.3105 g/L

# %% [markdown]
# #### **Questão 4. Equilíbrio em coluna de destilação com seletividade dependente da temperatura** - Um processo modelado com três estágios separa uma mistura etanol/água. A fração molar líquida de etanol (xi) e a temperatura (Ti) em cada estágio são conhecidas. O equilíbrio líquido-vapor é dado por:
#
# ![image.png](data:image/png;base64,...)
#
# Com a seguinte expressão linear para a seletividade α(T) = 2.5 − 0.01 · (T − 78).
#
# Os dados para os três estágios são:
#
# ![Captura de tela 2025-07-23 142018.png](data:image/png;base64,...)
#
# Escreva um código modular que calcule e exiba a seletividade αi em cada estágio e a fração yi com base nos dados acima.

# %%
from dataclasses import dataclass
from tabulate import tabulate

@dataclass
class ParametrosEstagios:
    estagio: str
    xi: float    # Fração molar líquida do etanol
    Ti: float    # Temperatura (°C)

# Cálculo das funções
def calculo_alpha(Ti):
    return 2.5 - 0.01 * (Ti - 78)

def calculo_yi(xi, Ti):
    alpha = calculo_alpha(Ti)
    return (alpha * xi) / (1 + (alpha - 1) * xi)

# Lista de estágios
estagios = [
    ParametrosEstagios("Topo", 0.20, 78),
    ParametrosEstagios("Alimentação", 0.40, 80),
    ParametrosEstagios("Fundo", 0.60, 85)
]

tabela_resultados = []
for estagio in estagios:
    alpha = calculo_alpha(estagio.Ti)
    yi = calculo_yi(estagio.xi, estagio.Ti)
    tabela_resultados.append([
        estagio.estagio,
        f"{estagio.Ti} °C",
        f"{estagio.xi:.2f}",
        f"{alpha:.4f}",
        f"{yi:.4f}"
    ])

headers = ["Estágio", "Temperatura (Tᵢ)", "Fração líquida (xᵢ)", "Seletividade (αᵢ)", "Fração no vapor (yᵢ)"]
print(tabulate(tabela_resultados, headers=headers, tablefmt="grid"))
# Out:
# +-------------+--------------------+-----------------------+---------------------+------------------------+
# | Estágio     | Temperatura (Tᵢ)   |   Fração líquida (xᵢ) |   Seletividade (αᵢ) |   Fração no vapor (yᵢ) |
# +=============+====================+=======================+=====================+========================+
# | Topo        | 78 °C              |                   0.2 |                2.5  |                 0.3846 |
# +-------------+--------------------+-----------------------+---------------------+------------------------+
# | Alimentação | 80 °C              |                   0.4 |                2.48 |                 0.6231 |
# +-------------+--------------------+-----------------------+---------------------+------------------------+
# | Fundo       | 85 °C              |                   0.6 |                2.43 |                 0.7847 |
# +-------------+--------------------+-----------------------+---------------------+------------------------+
